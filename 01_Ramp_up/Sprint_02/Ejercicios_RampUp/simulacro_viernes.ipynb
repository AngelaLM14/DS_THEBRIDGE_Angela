# %% [markdown]
# # Simulacro Rampup

# %%
# Escribe tu nombre y apellidos (apellido si solo tienes uno) en las variables:
nombre = "Ángela"
apellidos = "López Molina"

# %%
# Solo ejecutar
nombre_apellidos = nombre + ' ' + apellidos
print("Bienvenido", nombre_apellidos + '. Mucha suerte!')
# Out:
# Bienvenido Ángela López Molina. Mucha suerte!

# %% [markdown]
# ### Ejercicio 1: Calculadoras (3 puntos)

# %% [markdown]
# Construye un programa que:
#
# - Salude al usuario por su nombre
# - Le pregunte si quiere sumar, restar, multiplicar o dividir
# - Pida que introduzca 2 números de manera sucesiva
# - Devuelva el resultado de manera formal con un mensaje apropiado
#
# **Ayuda**: No se puede dividir por 0

# %%
nombre = input("Hola,¿cómo te llamas?")
print (f"Encantado, {nombre}, gracias por saludar.")
operacion = input(f'Dime, {nombre},¿qué operación quieres realizar: suma, resta, multiplicación o división?')
numeros = input("Ahora introduce los dos números que quieras operar.")
lista_numeros = numeros.split()
lista_numeros_int = [int(lista_numeros[0]), int(lista_numeros[1])]
print(f"De acuerdo, {nombre}, realizaremos una {operacion} entre {lista_numeros[0]} y {lista_numeros_int[1]} ")



for numeros in lista_numeros_int: 
    if operacion.lower() == "suma": 
        resultado = lista_numeros_int[0] + lista_numeros_int[1]
    elif operacion.lower() == "resta":
        resultado = lista_numeros_int[0] - lista_numeros_int[1]
    elif operacion.lower() == "multiplicación":
        resultado = lista_numeros_int[0] * lista_numeros_int[1]
    elif operacion.lower() == "división":
            if lista_numeros_int[1] == 0:
                raise ValueError ("No se puede dividir entre 0")
            resultado = lista_numeros_int[0] / lista_numeros_int[1]
    else:
        print("Operación no válida, por favor introduzca de nuevo los datos.")
    
print(f"El resultado de su {operacion} es {resultado}")
# Out:
# Encantado, Ángela, gracias por saludar.
# De acuerdo, Ángela, realizaremos una suma entre 4 y 9
# El resultado de su suma es 13

# %% [markdown]
# Construye una calculadora que sea como la anterior pero:
#
# - Acepte tantos valores de entrada como queramos
# - Devuelva mensajes con las cuentas que se van haciendo.
# - Permita salir con una palabra clave (exit, quit, ...)

# %%
nombre = input("Hola,¿cómo te llamas?")
print (f"Encantado, {nombre}, gracias por saludar.")
operacion = input(f'Dime, {nombre},¿qué operación quieres realizar: suma, resta, multiplicación o división?')
numeros = input("Ahora introduce los números que quieras operar.")
lista_numeros = numeros.split()
lista_numeros_int = [int(lista_numeros[0]), int(lista_numeros[1])]
print(f"De acuerdo, realizaremos una {operacion} con los números {lista_numeros_int}")

for i, numeros in enumerate(lista_numeros_int):
    while i < len(lista_numeros_int):
        if operacion.lower() == "suma": 
            resultado = 0
            resultado += lista_numeros_int[i]
        elif operacion.lower() == "resta":
            resultado = 0
            resultado -= lista_numeros_int[i]
        elif operacion.lower() == "multiplicación":
            resultado = 1
            resultado *= lista_numeros_int[i]
        elif operacion.lower == "división":
                if lista_numeros_int[1] == 0:
                    raise ValueError ("No se puede dividir entre 0")
                    break
                resultado = 1
                resultado /= resultado
        else:
            print("Operación no válida, por favor introduzca de nuevo los datos.")
            break
    
print(f"El resultado de su {operacion} es {resultado}")
# Out:
# Encantado, Ángela, gracias por saludar.
# De acuerdo, realizaremos una multiplicación con los números [4, 8]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Ángela López\Desktop\DS\DS_THEBRIDGE_Angela\Ramp_up\Sprint_02\Ejercicios_RampUp\simulacro_viernes.ipynb Cell 8 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/%C3%81ngela%20L%C3%B3pez/Desktop/DS/DS_THEBRIDGE_Angela/Ramp_up/Sprint_02/Ejercicios_RampUp/simulacro_viernes.ipynb#X10sZmlsZQ%3D%3D?line=11'>12</a>     resultado = 0
#      <a href='vscode-notebook-cell:/c%3A/Users/%C3%81ngela%20L%C3%B3pez/Desktop/DS/DS_THEBRIDGE_Angela/Ramp_up/Sprint_02/Ejercicios_RampUp/simulacro_viernes.ipynb#X10sZmlsZQ%3D%3D?line=12'>13</a>     resultado += lista_numeros_int[i]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/%C3%81ngela%20L%C3%B3pez/Desktop/DS/DS_THEBRIDGE_Angela/Ramp_up/Sprint_02/Ejercicios_RampUp/simulacro_viernes.ipynb#X10sZmlsZQ%3D%3D?line=13'>14</a> elif operacion.lower() == "resta":
#      <a href='vscode-notebook-cell:/c%3A/Users/%C3%81ngela%20L%C3%B3pez/Desktop/DS/DS_THEBRIDGE_Angela/Ramp_up/Sprint_02/Ejercicios_RampUp/simulacro_viernes.ipynb#X10sZmlsZQ%3D%3D?line=14'>15</a>     resultado = 0
#      <a href='vscode-notebook-cell:/c%3A/Users/%C3%81ngela%20L%C3%B3pez/Desktop/DS/DS_THEBRIDGE_Angela/Ramp_up/Sprint_02/Ejercicios_RampUp/simulacro_viernes.ipynb#X10sZmlsZQ%3D%3D?line=15'>16</a>     resultado -= lista_numeros_int[i]
#
# KeyboardInterrupt:

# %% [markdown]
# ### Ejercicio 2 (4 puntos)
#
# Escribe un programa que trabaje con 3 listas:
#
# La lista ***grupo_musical*** contiene strings.
#
# La lista ***generos*** contiene strings.
#
# La lista ***anios*** puede contener un entero o tuplas.
#
# Ejemplo de datos:
#
# >"ABBA"
# >
# >"pop"
# >
# >(1972, 1982)
#
# Otro ejemplo:
#
# >"Madonna"
# >
# >"pop"
# >
# >1983
#
# Otro ejemplo:
#
# >"Kölsch"
# >
# >"electronica"
# >
# >1995
#
# Un grupo musical solo puede tener un género musical.
# Un grupo musical debe tener como mínimo un año de formación, que es un entero.
# Un grupo musical, si tuviese año de disolución, la información se guardaría en una tupla.
#
# Se pide implementar:
#
# a. Una función llamada *inserta* que acepte 4 parámetros (grupo, genero, comienzo, fin). El fin por defecto debe ser un objeto nulo. El grupo se inserta en la lista de grupos. El genero se inserta en la lista de géneros. El comienzo o comienzo y fin se inserta en la lista de años. La función no tiene valor retornado.
#
# b. Una función *busca_genero* con un parámetro de tipo string (genero) y devuelve una lista con todos los grupos de ese género.
#
# c. Una función *busca_grupos* con un parámetro booleano llamado *activos* con un valor por defecto verdadero. Cuando el valor es verdadero, devuelve solo los grupos activos en una lista. Cuando *activos* es falso, devuelve todos los grupos disueltos en una lista.
#
# d. Una función *busca_genero_indice* con un parámetro de tipo string (genero) que devuelve una lista con los índices donde se encuentra ese género.
#
# e. Una función *filtra_listas_genero* con un parámetro de tipo string (genero) que devuelve una tupla con las 3 listas filtradas y ***llame*** a busca_genero_indice
#
# f. Una función *anios_activos* que no tenga parámetros de entrada ni valor retornado que imprima línea a línea la información: grupo musical ---> años activos. Es decir:
#
# >ABBA ---> 10 años activos
# >
# >Madonna --> 40 años activos
# >
# >Kölsch --> 25 años activos
#
#
# Nota: si no te sale un apartado después de un tiempo prudencial, ¡pasa al siguiente!

# %%
'''
Escribe un programa que trabaje con 3 listas:

* La lista ***grupo_musical*** contiene strings.

* La lista ***generos*** contiene strings.

* La lista ***anios*** puede contener un entero o tuplas.
'''

grupo_musical = ["Platero y tú", "Madonna", "ABBA"]
generos = ["rock","pop", "pop"]
anios = [(1989-2002),(1972, 1982)]

# %%
'''Una función llamada *inserta* que acepte 4 parámetros (grupo, genero, comienzo, fin). 
El fin por defecto debe ser un objeto nulo. El grupo se inserta en la lista de grupos. 
El genero se inserta en la lista de géneros. 
El comienzo o comienzo y fin se inserta en la lista de años. 
La función no tiene valor retornado.'''

def inserta(grupo,genero,comienzo,fin=None): 
    grupo_musical.append(grupo)
    generos.append(genero)
    if fin != None:
        anios.append(tuple(comienzo,fin))
    else: 
        anios.append(comienzo)

inserta("La La Love You","indie",1996)

# %%
print(grupo_musical)
print(generos)
print(anios)
# Out:
# ['Platero y tú', 'Madonna', 'ABBA', 'La La Love You', 'La La Love You']
# ['rock', 'pop', 'pop', 'indie', 'indie']
# [-13, (1972, 1982), 1996]

# %%
'''Una función *busca_genero* con un parámetro de tipo string (genero) 
y devuelve una lista con todos los grupos de ese género.'''

def busca_genero (genero):
    lista_grupo = []
    for indice, genero_dest, in enumerate(generos):
        if genero == genero_dest:
            lista_grupo.append(grupo_musical[indice])
    return lista_grupo
        
busca_genero("indie")
# Out:
# ['La La Love You', 'La La Love You']

# %%
''' 
Una función *busca_grupos* con un parámetro booleano llamado *activos* con un valor por defecto verdadero. 
Cuando el valor es verdadero, devuelve solo los grupos activos en una lista. Cuando *activos* es falso, 
devuelve todos los grupos disueltos en una lista.
'''
def busca_grupos (activos = True):
    grupos_activos = []
    for indice, anyos in anyos:
        if type (anyo) == int and activos:
            grupos_activos.append(indice)
        elif type(anyo) == tuple and not activos:
            grupos_activos.append(grupos[indice])
    return grupos_activos
    
busca_grupos("ABBA")
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# c:\Users\Ángela López\Desktop\DS\DS_THEBRIDGE_Angela\Ramp_up\Sprint_02\Ejercicios_RampUp\simulacro_viernes.ipynb Cell 14 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/%C3%81ngela%20L%C3%B3pez/Desktop/DS/DS_THEBRIDGE_Angela/Ramp_up/Sprint_02/Ejercicios_RampUp/simulacro_viernes.ipynb#X34sZmlsZQ%3D%3D?line=11'>12</a>             grupos_activos.append(grupos[indice])
#      <a href='vscode-notebook-cell:/c%3A/Users/%C3%81ngela%20L%C3%B3pez/Desktop/DS/DS_THEBRIDGE_Angela/Ramp_up/Sprint_02/Ejercicios_RampUp/simulacro_viernes.ipynb#X34sZmlsZQ%3D%3D?line=12'>13</a>     return grupos_activos
# ---> <a href='vscode-notebook-cell:/c%3A/Users/%C3%81ngela%20L%C3%B3pez/Desktop/DS/DS_THEBRIDGE_Angela/Ramp_up/Sprint_02/Ejercicios_RampUp/simulacro_viernes.ipynb#X34sZmlsZQ%3D%3D?line=14'>15</a> busca_grupos("ABBA")
#
# c:\Users\Ángela López\Desktop\DS\DS_THEBRIDGE_Angela\Ramp_up\Sprint_02\Ejercicios_RampUp\simulacro_viernes.ipynb Cell 14 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/%C3%81ngela%20L%C3%B3pez/Desktop/DS/DS_THEBRIDGE_Angela/Ramp_up/Sprint_02/Ejercicios_RampUp/simulacro_viernes.ipynb#X34sZmlsZQ%3D%3D?line=5'>6</a> def busca_grupos (activos = True):
#       <a href='vscode-notebook-cell:/c%3A/Users/%C3%81ngela%20L%C3%B3pez/Desktop/DS/DS_THEBRIDGE_Angela/Ramp_up/Sprint_02/Ejercicios_RampUp/simulacro_viernes.ipynb#X34sZmlsZQ%3D%3D?line=6'>7</a>     grupos_activos = []
# ----> <a href='vscode-notebook-cell:/c%3A/Users/%C3%81ngela%20L%C3%B3pez/Desktop/DS/DS_THEBRIDGE_Angela/Ramp_up/Sprint_02/Ejercicios_RampUp/simulacro_viernes.ipynb#X34sZmlsZQ%3D%3D?line=7'>8</a>     for indice, anyos in anyos:
#       <a href='vscode-notebook-cell:/c%3A/Users/%C3%81ngela%20L%C3%B3pez/Desktop/DS/DS_THEBRIDGE_Angela/Ramp_up/Sprint_02/Ejercicios_RampUp/simulacro_viernes.ipynb#X34sZmlsZQ%3D%3D?line=8'>9</a>         if type (anyo) == int and activos:
#      <a href='vscode-notebook-cell:/c%3A/Users/%C3%81ngela%20L%C3%B3pez/Desktop/DS/DS_THEBRIDGE_Angela/Ramp_up/Sprint_02/Ejercicios_RampUp/simulacro_viernes.ipynb#X34sZmlsZQ%3D%3D?line=9'>10</a>             grupos_activos.append(indice)
#
# UnboundLocalError: cannot access local variable 'anyos' where it is not associated with a value

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
def filtra_genero(genero):
    indices = busca_genero(genero)
    lista_grupos = []
    lista_generos = []
    lista_anyos = []
    for indice in indices:
        lista_grupos.append(grupos[indice])
        lista_generos.append(generos[indice])
        lista_anyos.append(anyos[indice])
    return(lista_grupos,lista_generos,lista_anyos)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def anyos_activo():
    anyo_actual = 2023
    for indice, grupo in enumerate.grupos:
        datos_tiempo = anyos[indice]
        if type(datos_tiempo) == int:
            activos = anyo_actual - datos_tiempo
        else:
            activos = datos_tiempo[1] - datos_tiempo [0]
        print()

# %% [markdown]
# ### Ejercicio 3 (3 puntos)
#
# #### Crear un programa que calcule la cuota de una hipoteca
#
# Las cuotas hipotecarias se calculan utilizando la fórmula del interés francés.
#
# La fórmula del interés francés es la siguiente:
# \begin{align*}
# C=V \frac{(1+i)^n i}{(1+i)^n -1}
# \end{align*}
#
#
#     C = cuota a pagar (mensual)
#     V = volumen del préstamo hipotecario
#     i = tipo de interés del período (mensual)
#     n = número de cuotas (mensuales)

# %% [markdown]
# 1. Crea un programa que solicite al usuario los datos de su hipoteca mediante input() los datos (volumen, interés **anual**, y plazo en **años**) y le devuelva la cuota **mensual** a pagar. No es necesario encapsularlo en funciones. (0.4)

# %% [markdown]
# 2. Crea una función `calcular_hip` que realiza el cálculo y cuyos argumentos de entrada sean `volumen`, `interes_anual` y `años`, devolviendo la couta mensual(float). El argumento de `años` deberá de tener un valor por defecto de 30. Documenta la función con el estilo de Google.  (0.4)

# %% [markdown]
# 3. Calcula la cuota y guárdala en la variable `res_cuota` si la cantidad de la hipoteca son 350000 euros, el interés anual es del 5% y la quiere pagar en 20 años a partir de la función `calcular_hip`. (0.4)

# %% [markdown]
# 4. Crea una función `gasto_vivienda`, con dos argumentos de entrada `ingreso` y `lista_hip`. Esta lista tendrá los 3 valores de los argumentos de entrada de `calcular_hip`, llamando a esta función desde dentro de `gasto_vivienda`. Tiene que devolver el valor del porcentaje de gasto en la hipoteca respecto a los ingresos. (Entre 0 y 1, es decir 0.5 si es del 50%) Documenta la función. (0.4)

# %% [markdown]
# 5. Calcula el porcentaje de gasto en la hipoteca si el ingreso es de 1700 euros y guárdalo en la variable `res_porcentaje` a partir de la función `gasto_vivienda`. (0.4)
