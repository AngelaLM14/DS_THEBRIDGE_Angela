# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### #1
#
# Importa Pandas y ajusta la opción display.max_columns a None y la opción display.max_coldwidth a 50.

# %% [markdown]
# ### #2
#
# Lee el fichero "food_100.csv" y muestra sus primeras 10 líneas, y sólo esas

# %% [markdown]
# ### #3
#
# Muestra la info principal. ¿Hay nulos, dónde?

# %% [markdown]
# ### #4
#
# Muestra la medidas de tendencia central y de posición de las columnas numéricas

# %% [markdown]
# ### #5
#
# ¿Cuántos elementos hay en el dataset?

# %% [markdown]
# ### #6
#
# ¿Cuántas columnas hay en el dataset? No las muestres sólo usa comandos Python y pandas para mostrar el número de columnas

# %% [markdown]
# ### #7
#
# Ahora sí muestra todas las columnas, una por línea.

# %% [markdown]
# ### #8
#
# ¿Cuál es el nombre de la columna 105?

# %% [markdown]
# ### #9
#
# Muestra los tipos de la columna 104, y luego el tipo de las 10 primeras columnas

# %% [markdown]
# ### #10
#
# Muestra el índice del dataframe y sólo el índice.

# %% [markdown]
# ### #11
#
# ¿Cuál es el valor de la columna "product_name" del elemento en la posición 18? Muéstralo de dos formas diferentes.
